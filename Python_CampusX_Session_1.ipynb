# %% [markdown]
# <a href="https://colab.research.google.com/github/veerpast/todoapp/blob/main/Python_CampusX_Session_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello')
# Out:
# hello

# %%
input('what is your name ')
# Out:
# what is your name veer
# 'veer'

# %%
fnum = input('enter first number ')
print(fnum)
snum = input('enter second number ')
print(snum)
fnum = int(fnum)
snum = int(snum)
result = fnum + snum
print(result)
print(type(fnum))
# Out:
# enter first number 45
# 45
# enter second number 56
# 56
# 101
# <class 'int'>
